# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test = pd.read_csv("/Users/bandari/Downloads/AF45_100x_Zeiss_300um_1550nm_1000mmmin_67.5nJ.csv", delimiter=";")

# %%
plt.plot(test.transpose()[0])
plt.show()
